# %% [markdown]
# # Model Evaluation Results
#
# This notebook compares the evaluation metrics across different model versions.

# %%
import os
import sys
import json
import pandas as pd

sys.path.append(os.path.abspath("../"))

from pipeline.version_config import VersionConfig
from pipeline.pipeline_run import PipelineRun
from pipeline.factory import PipelineFactory
from pipeline.stages import eda
from utils.snapshot_model import compare_models, ModelType, save_comparison_to_gcs

# %%
IMAGES_FOLDER = "../../../images/results/"
dry_run = True

config = VersionConfig.load().build()
run = PipelineRun(config, eda_config={"fig_size": (14, 7), "palette": "Set2"})
stages = PipelineFactory.validate_current(config)
# Out:
# VersionConfig loaded:
#   data:          v3.4 (raw_suffix='real')
#   baselines:     v4.0
#   model:         v5.1
#   hyperparams:   v1.1
#   use_synthetic: False
#
# VersionConfig ready:
#   Active flags      : ['none (dry run)']
#   data              : v3.4 (unchanged)
#   baselines         : v4.0 (unchanged)
#   model             : v5.1 (unchanged)
#   hyperparams       : v1.1 (unchanged)
#   raw_version       : v3.4_real
#   next_final_version: v3.4_100real
#   model_version     : v5.1
#   baselines_version : v4.0
#   hyperparam_version: v1.1
#   use_synthetic     : False

# %%
# Load data from GCS parquet snapshot, run pipeline through scaler, then load v5.1 model .pkl files.
# No BigQuery call, no retraining.
stages.loader.run(run)
stages.preprocessor.run(run)
stages.engineer.run(run)
stages.splitter.run(run)
stages.scaler.run(run)
stages.model_loader.run(run)
# Out:
# Loaded snapshot 'v3.4_real': 60696 rows from 2026-04-29
#   Polls: {'upload': 21398, '24h': 20906, '7d': 18392}
# Loaded baselines 'v4.0': 28814 baseline videos, 974 median rows (974 channels)
# ...
# Building clean dataset
# ...
# snapshot cols: Index(['video_id', 'poll_timestamp', 'channel_id', 'channel_handle', 'title',
#        'view_count', 'like_count', 'comment_count', 'face_count', 'brightness',
#        'colorfulness', 'vertical', 'tier', 'description', 'tags',
#        'duration_seconds', 'category_id', 'category_name', 'published_at',
#        'poll_label', 'hours_since_publish', 'subscriber_count',
#        'contains_synthetic_media'],
#       dtype='object')
#
# [1/3] Pivoting snapshots...
#   Videos with all 3 polls: 18334 (dropped 3111 incomplete)
#   Pivoted shape: (18403, 34)
#
# [2/3] Joining baseline medians...
#   Baseline join: 18403/18403 videos matched a channel median
#
# [3/3] Cleaning data...
#   Cleaned: 18403 rows × 40 columns
#
# ...

# %%
models_df = compare_models()
eda.load_model_comparison(run)
print(models_df.tail(10))
print(models_df.columns)
# Out:
# Loaded 25 model snapshots
# Loaded 25 model snapshots
#                        model_type data_snapshot training_date  real_rows  \
# version
# v4.0_rf              RandomForest  v3.2_100real    2026-04-27       9554
# v4.0_xgb                  XGBoost  v3.2_100real    2026-04-27       9554
# v5.0_ensemble    VotingClassifier  v3.3_100real    2026-04-29      10236
# v5.0_lr_l1     LogisticRegression  v3.3_100real    2026-04-29      10236
# v5.0_rf              RandomForest  v3.3_100real    2026-04-29      10236
# v5.0_xgb                  XGBoost  v3.3_100real    2026-04-29      10236
# v5.1_ensemble    VotingClassifier  v3.4_100real    2026-04-29      10236
# v5.1_lr_l1     LogisticRegression  v3.4_100real    2026-04-29      10236
# v5.1_rf              RandomForest  v3.4_100real    2026-04-29      10236
# v5.1_xgb                  XGBoost  v3.4_100real    2026-04-29      10236
#
#                synth_rows  accuracy  roc_auc  precision_above  recall_above  \
# version
# ...

# %% [markdown]
# ## Model Comparison Plots
#
# All functions accept `compare_versions` and `model_type` filters:
# - `compare_versions`: `"all"`, `"last2versions"`, `"last3versions"`, or a list of version prefix substrings e.g. `["v4.0", "v5.1"]`
# - `model_type`: `None` (all), or a `ModelType` enum e.g. `ModelType.XGB`
#
# The dashed vertical line marks the eval methodology change: models left of the line were evaluated on a held-out test split from the same data snapshot; models to the right were evaluated on a shared validation hold-out set created at v4.0. Cross-boundary metric comparisons are directional, not apples-to-apples.

# %% [markdown]
# ROC-AUC trajectory by model type across all trained versions; the dashed vertical line marks the eval methodology change at v4.0 where a shared holdout set was introduced.

# %%
eda.plot_roc_auc(run, save_figure_name=f"{IMAGES_FOLDER}roc_auc_by_version_line.png")

# %% [markdown]
# ROC curves for all four model types at the current version, showing true positive rate vs. false positive rate across classification thresholds.

# %%
eda.plot_roc_curves(run, save_figure_name=f"{IMAGES_FOLDER}roc_auc_curve.png")
# Out:
# /Users/jelanigould-bailey/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/jelanigould-bailey/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /Users/jelanigould-bailey/opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Overall accuracy by model type across versions, with the methodology-change boundary marked.

# %%
eda.plot_accuracy(run, save_figure_name=f"{IMAGES_FOLDER}accuracy_by_model.png")

# %% [markdown]
# Precision and recall broken down by model type and class (above / below baseline), highlighting asymmetric trade-offs between the two prediction targets.

# %%
eda.plot_precision_recall(run, save_figure_name=f"{IMAGES_FOLDER}precision_recall_by_model.png")

# %% [markdown]
# F1 scores by model type and class across versions, combining precision and recall into a single measure of classification quality per label.

# %%
eda.plot_f1(run, save_figure_name=f"{IMAGES_FOLDER}f1_by_model.png")

# %% [markdown]
# Accuracy as a function of training data composition (real vs. synthetic row counts), showing the impact of synthetic data augmentation on model performance.

# %%
eda.plot_data_composition_vs_accuracy(run, save_figure_name=f"{IMAGES_FOLDER}data_composition_accuracy.png")

# %% [markdown]
# Top XGBoost feature importances tracked across all trained versions, revealing which signals have been consistently predictive as the dataset has evolved.

# %%
# Feature importance trajectory for XGB across all versions.
# Change model_type or compare_versions to slice differently.
eda.plot_top_features_over_time(run, ModelType.XGB, save_figure_name=f"{IMAGES_FOLDER}features_over_time_xgb.png")
# Out:
# Loaded 25 model snapshots

# %% [markdown]
# Feature importances for the current XGBoost model ranked by magnitude, identifying the strongest predictors of above-baseline performance.

# %%
eda.plot_feature_importance(run, model_name="xgb", save_figure_name=f"{IMAGES_FOLDER}feature_importance_xgb.png")

# %% [markdown]
# Engagement distributions for Shorts vs. long-form videos in `df_engineered`, confirming that duration-based segmentation captures meaningfully different engagement patterns.

# %%
eda.set_active_df(run, run.df_engineered)
eda.plot_is_short_engagement(run, save_figure_name=f"{IMAGES_FOLDER}shorts_engagement.png")
# Out:
# /Users/jelanigould-bailey/Desktop/uc_berkeley_capstone_repo/repo/src/capstone/pipeline/stages/eda.py:809: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /Users/jelanigould-bailey/Desktop/uc_berkeley_capstone_repo/repo/src/capstone/pipeline/stages/eda.py:809: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
# Write model comparison snapshot to GCS (overwrites evals/model_comparison.jsonl).
if not dry_run:
    save_comparison_to_gcs(models_df)

# %%
# Store the results locally (e.g. for loading into LLM context)
if not dry_run:
    models_df.to_csv('../../../data/model_results_df.csv', index=False)
